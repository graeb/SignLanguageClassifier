# %%
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
# Sigmoid
x = np.linspace(-5,5, 50)
y = 1 /( 1 + (np.e ** -x))
ax = plt.gca()
ax.spines['top'].set_color('none')
ax.spines['left'].set_position('zero')
ax.spines['right'].set_color('none')
ax.spines['bottom'].set_position('zero')
plt.grid(visible=True)
plt.plot(x,y)

# %%
#sigmoid
t = np.linspace(-10, 10, 100)
sig = 1 / (1 + np.exp(-t))

# plt.axhline(y=0, color="black", linestyle="--")
plt.axhline(y=0.5, color="black", linestyle=":")
# plt.axhline(y=1.0, color="black", linestyle="--")
plt.grid(visible=True)
plt.axvline(color="grey")
# plt.axline((0, 0.5), slope=0.25, color="black", linestyle=(0, (5, 5)))
plt.plot(t, sig, linewidth=2, label=r"$\sigma(t) = \frac{1}{1 + e^{-t}}$")
plt.xlim(-10, 10)
plt.legend(fontsize=14)
plt.show()

# %%
#tanh
t = np.linspace(-10, 10, 100)
tanh = (np.exp(t) - np.exp(-t)) / (np.exp(t) + np.exp(-t))

# plt.axhline(y=0, color="black", linestyle="--")
plt.axhline(y=0, color="black", linestyle=":")
# plt.axhline(y=1.0, color="black", linestyle="--")
plt.grid(visible=True)
plt.axvline(color="grey")
# plt.axline((0, 0.5), slope=0.25, color="black", linestyle=(0, (5, 5)))
plt.plot(t, tanh, linewidth=2, label=r"$\tanh(t) = \frac{e^{x} - e^{-x}}{e^{x} + e^{-x}}$")
plt.xlim(-10, 10)
plt.legend(fontsize=14)
plt.show()

# %%
#ReLU

def relu_fun(x):
    return np.maximum(0.0, x)

t = np.linspace(-10, 10, 100)
relu = relu_fun(t)

# plt.axhline(y=0, color="black", linestyle="--")
plt.axhline(y=0, color="black", linestyle=":")
# plt.axhline(y=1.0, color="black", linestyle="--")
plt.grid(visible=True)
plt.axvline(color="grey")
# plt.axline((0, 0.5), slope=0.25, color="black", linestyle=(0, (5, 5)))
plt.plot(t, relu, linewidth=2, label=r'$ReLU(t) = max(0, t)$')
plt.xlim(-10, 10)
plt.legend(fontsize=14)
plt.show()

# %%
# Leaky ReLU
def leaky_relu(x):
    if x>0 :
        return x
    else:
        return 0.01*x
    
t = np.linspace(-10, 10, 100)
relu = relu_fun(t)

# plt.axhline(y=0, color="black", linestyle="--")
plt.axhline(y=0, color="black", linestyle=":")
# plt.axhline(y=1.0, color="black", linestyle="--")
plt.grid(visible=True)
plt.axvline(color="grey")
# plt.axline((0, 0.5), slope=0.25, color="black", linestyle=(0, (5, 5)))
plt.plot(t, relu, linewidth=2, label=r"$\tanh(t) = \frac{e^{x} - e^{-x}}{e^{x} + e^{-x}}$")
plt.xlim(-10, 10)
plt.legend(fontsize=14)
plt.show()
