# %%
from torchvision import models
from torchsummary import summary
import torch
# dropout = {'dropout': 0.3}
vgg = models.inception_v3()
summary(vgg, (3, 299, 299))
# Out:
# c:\Users\graeb\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\models\inception.py:43: FutureWarning: The default weight initialization of inception_v3 will be changed in future releases of torchvision. If you wish to keep the old behavior (which leads to long initialization times due to scipy/scipy#11299), please set init_weights=True.
#   warnings.warn(
# ...
# Layer (type:depth-idx)                   Output Shape              Param #
# ...
# ├─BasicConv2d: 1-1                       [-1, 32, 149, 149]        --
# |    └─Conv2d: 2-1                       [-1, 32, 149, 149]        864
# |    └─BatchNorm2d: 2-2                  [-1, 32, 149, 149]        64
# ├─BasicConv2d: 1-2                       [-1, 32, 147, 147]        --
# |    └─Conv2d: 2-3                       [-1, 32, 147, 147]        9,216
# |    └─BatchNorm2d: 2-4                  [-1, 32, 147, 147]        64
# ├─BasicConv2d: 1-3                       [-1, 64, 147, 147]        --
# ...

# %%
t = torch.cuda.get_device_properties(0).total_memory
r = torch.cuda.memory_reserved(0)
a = torch.cuda.memory_allocated(0)
f = r-a  # free inside reserved
f = f / 1024
print(f'Total memory is {t}')
print(f'Reserved memory is {r}')
print(f'Allocated memory is {a}')
print(f'Free inside reserved memory is {f}')
# Out:
# Total memory is 4294705152
# Reserved memory is 2323644416
# Allocated memory is 2218912256
# Free inside reserved memory is 102277.5

# %%
from pynvml import *
nvmlInit()
h = nvmlDeviceGetHandleByIndex(0)
info = nvmlDeviceGetMemoryInfo(h)
print(f'total    : {info.total}')
print(f'free     : {info.free}')
print(f'used     : {info.used}')
# Out:
# total    : 4294967296
# free     : 124940288
# used     : 4170027008

# %%
torch.cuda.empty_cache()

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
total, used = torch.cuda.mem_get_info(device)
total, used = used  / 1e+6, total  / 1e+6
print(f'total: {total}, used: {used}')
# Out:
# total: 4294.705152, used: 0.0
